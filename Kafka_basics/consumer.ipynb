# %%
from kafka import KafkaConsumer
import json

# %%
consumer = KafkaConsumer(
    "demo-topic",
    bootstrap_servers= "kafka:9092",
    auto_offset_reset= "earliest",
    value_deserializer=lambda x: json.loads(x.decode("utf-8"))
)
# Out:
# /tmp/ipykernel_156/2310114348.py:1: DeprecationWarning: value_deserializer does not implement kafka.serializer.Deserializer
#   consumer = KafkaConsumer(

# %%
for msg in consumer:
    print(msg.value)
# Out:
# {'id': 0, 'name': 'Student-0'}
# {'id': 1, 'name': 'Student-1'}
# {'id': 2, 'name': 'Student-2'}
# {'id': 3, 'name': 'Student-3'}
# {'id': 4, 'name': 'Student-4'}
# {'id': 5, 'name': 'Student-5'}
# {'id': 6, 'name': 'Student-6'}
# {'id': 7, 'name': 'Student-7'}
# {'id': 8, 'name': 'Student-8'}
# {'id': 9, 'name': 'Student-9'}
